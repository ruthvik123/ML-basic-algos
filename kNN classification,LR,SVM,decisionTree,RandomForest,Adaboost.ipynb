# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot
# %matplotlib inline

# %%
import os

# %%
os.chdir("C:\\Users\\ruthvikudutha\\Desktop\\Data Sets")

# %%
data1 = pd.read_csv("data.csv")

# %%
data1
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M       17.990         10.38          122.80     1001.0
# 1      842517         M       20.570         17.77          132.90     1326.0
# 2    84300903         M       19.690         21.25          130.00     1203.0
# 3    84348301         M       11.420         20.38           77.58      386.1
# 4    84358402         M       20.290         14.34          135.10     1297.0
# 5      843786         M       12.450         15.70           82.57      477.1
# 6      844359         M       18.250         19.98          119.60     1040.0
# 7    84458202         M       13.710         20.83           90.20      577.9
# 8      844981         M       13.000         21.82           87.50      519.8
# 9    84501001         M       12.460         24.04           83.97      475.9
# 10     845636         M       16.020         23.24          102.70      797.8
# ...

# %%
# drop the 1st coloumn as it is useless  identifier
data1 = data1.drop(["id"], axis=1)

# %%
data1
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           M       17.990         10.38          122.80     1001.0
# 1           M       20.570         17.77          132.90     1326.0
# 2           M       19.690         21.25          130.00     1203.0
# 3           M       11.420         20.38           77.58      386.1
# 4           M       20.290         14.34          135.10     1297.0
# 5           M       12.450         15.70           82.57      477.1
# 6           M       18.250         19.98          119.60     1040.0
# 7           M       13.710         20.83           90.20      577.9
# 8           M       13.000         21.82           87.50      519.8
# 9           M       12.460         24.04           83.97      475.9
# 10          M       16.020         23.24          102.70      797.8
# 11          M       15.780         17.89          103.60      781.0
# 12          M       19.170         24.80          132.40     1123.0
# ...

# %%
# EXAMINE THE TARGET VARIABLES 'DIAGNOSIS' WHICH IS THE TARGET VARIABLE
# get a count of diagnosis observations by type
data1["diagnosis"].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
# recode the target variable 'diagnsis' to contain the labels "Malignant" and "Benign"
data1["diagnosis"].replace(["M","B"],["Malignant","Benign"],inplace = True)

# %%
data1
# Out:
#      diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    Malignant       17.990         10.38          122.80     1001.0
# 1    Malignant       20.570         17.77          132.90     1326.0
# 2    Malignant       19.690         21.25          130.00     1203.0
# 3    Malignant       11.420         20.38           77.58      386.1
# 4    Malignant       20.290         14.34          135.10     1297.0
# 5    Malignant       12.450         15.70           82.57      477.1
# 6    Malignant       18.250         19.98          119.60     1040.0
# 7    Malignant       13.710         20.83           90.20      577.9
# 8    Malignant       13.000         21.82           87.50      519.8
# 9    Malignant       12.460         24.04           83.97      475.9
# 10   Malignant       16.020         23.24          102.70      797.8
# 11   Malignant       15.780         17.89          103.60      781.0
# 12   Malignant       19.170         24.80          132.40     1123.0
# ...

# %%
x = data1.loc[:,["radius_mean","area_mean","smoothness_mean"]]

# %%
x.describe()   # summary statistics
# Out:
#        radius_mean    area_mean  smoothness_mean
# count   569.000000   569.000000       569.000000
# mean     14.127292   654.889104         0.096360
# std       3.524049   351.914129         0.014064
# min       6.981000   143.500000         0.052630
# 25%      11.700000   420.300000         0.086370
# 50%      13.370000   551.100000         0.095870
# 75%      15.780000   782.700000         0.105300
# max      28.110000  2501.000000         0.163400

# %%
x = data1.iloc[:,1:31]
y = data1.iloc[:,0]              # seperating independent and dependent variables

# %%
x
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0         17.990         10.38          122.80     1001.0          0.11840
# 1         20.570         17.77          132.90     1326.0          0.08474
# 2         19.690         21.25          130.00     1203.0          0.10960
# 3         11.420         20.38           77.58      386.1          0.14250
# 4         20.290         14.34          135.10     1297.0          0.10030
# 5         12.450         15.70           82.57      477.1          0.12780
# 6         18.250         19.98          119.60     1040.0          0.09463
# 7         13.710         20.83           90.20      577.9          0.11890
# 8         13.000         21.82           87.50      519.8          0.12730
# 9         12.460         24.04           83.97      475.9          0.11860
# 10        16.020         23.24          102.70      797.8          0.08206
# ...

# %%
y
# Out:
# 0      Malignant
# 1      Malignant
# 2      Malignant
# 3      Malignant
# 4      Malignant
# 5      Malignant
# 6      Malignant
# 7      Malignant
# 8      Malignant
# 9      Malignant
# 10     Malignant
# 11     Malignant
# 12     Malignant
# 13     Malignant
# 14     Malignant
# 15     Malignant
# 16     Malignant
# 17     Malignant
# 18     Malignant
# 19        Benign
# 20        Benign
# 21        Benign
# 22     Malignant
# 23     Malignant
# 24     Malignant
# 25     Malignant
# 26     Malignant
# 27     Malignant
# 28     Malignant
# 29     Malignant
#          ...
# 539       Benign
# 540       Benign
# 541       Benign
# 542       Benign
# 543       Benign
# 544       Benign
# 545       Benign
# 546       Benign
# 547       Benign
# 548       Benign
# 549       Benign
# 550       Benign
# 551       Benign
# 552       Benign
# 553       Benign
# 554       Benign
# 555       Benign
# 556       Benign
# 557       Benign
# 558       Benign
# 559       Benign
# ...

# %%
# apply normalization to rescale th features to a standard range of values.
#normalize the numeric variables from column 2 to column 31 in the main data frame

from  sklearn import preprocessing 
minmax = preprocessing.MinMaxScaler(feature_range = (0,1))
minmax.fit(x).transform(x)
# Out:
# array([[0.52103744, 0.0226581 , 0.54598853, ..., 0.91202749, 0.59846245,
#         0.41886396],
#        [0.64314449, 0.27257355, 0.61578329, ..., 0.63917526, 0.23358959,
#         0.22287813],
#        [0.60149557, 0.3902604 , 0.59574321, ..., 0.83505155, 0.40370589,
#         0.21343303],
#        ...,
#        [0.45525108, 0.62123774, 0.44578813, ..., 0.48728522, 0.12872068,
#         0.1519087 ],
#        [0.64456434, 0.66351031, 0.66553797, ..., 0.91065292, 0.49714173,
#         0.45231536],
#        [0.03686876, 0.50152181, 0.02853984, ..., 0.        , 0.25744136,
#         0.10068215]])

# %%
minmax
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
# divide the test and train data
from sklearn import cross_validation, neighbors
from sklearn.cross_validation import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)
# Out:
# C:\Users\ruthvikudutha\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
x_train
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 211       11.840         18.94           75.51      428.0          0.08871
# 145       11.900         14.65           78.11      432.8          0.11520
# 461       27.420         26.27          186.90     2501.0          0.10840
# 287       12.890         13.12           81.89      515.9          0.06955
# 427       10.800         21.98           68.79      359.9          0.08801
# 506       12.220         20.04           79.47      453.1          0.10960
# 245       10.480         19.86           66.72      337.7          0.10700
# 379       11.080         18.83           73.30      361.6          0.12160
# 518       12.880         18.22           84.45      493.1          0.12180
# 312       12.760         13.37           82.29      504.1          0.08794
# 426       10.480         14.98           67.49      333.6          0.09816
# ...

# %%
y_train
# Out:
# 211       Benign
# 145       Benign
# 461    Malignant
# 287       Benign
# 427       Benign
# 506       Benign
# 245       Benign
# 379    Malignant
# 518       Benign
# 312       Benign
# 426       Benign
# 238       Benign
# 494       Benign
# 323    Malignant
# 291       Benign
# 100    Malignant
# 14     Malignant
# 458       Benign
# 279       Benign
# 176       Benign
# 388       Benign
# 131    Malignant
# 132    Malignant
# 546       Benign
# 500       Benign
# 481       Benign
# 15     Malignant
# 109       Benign
# 490       Benign
# 509    Malignant
#          ...
# 394       Benign
# 304       Benign
# 433    Malignant
# 269       Benign
# 112       Benign
# 118    Malignant
# 219    Malignant
# 370    Malignant
# 341       Benign
# 522       Benign
# 143       Benign
# 66        Benign
# 209       Benign
# 475       Benign
# 92        Benign
# 37        Benign
# 175       Benign
# 529       Benign
# 376       Benign
# 338       Benign
# 301       Benign
# ...

# %%
x["area_mean"].hist()

# %%
# fitting classifier to the training set
clf = neighbors.KNeighborsClassifier()
clf.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform')

# %%
# predicting the test score results
y_pred = clf.predict(x_test)

# %%
y_pred
# Out:
# array(['Malignant', 'Benign', 'Benign', 'Benign', 'Malignant', 'Benign',
#        'Benign', 'Benign', 'Benign', 'Benign', 'Malignant', 'Benign',
#        'Malignant', 'Malignant', 'Malignant', 'Benign', 'Benign',
#        'Benign', 'Malignant', 'Benign', 'Malignant', 'Benign', 'Benign',
#        'Benign', 'Benign', 'Benign', 'Malignant', 'Malignant', 'Benign',
#        'Benign', 'Malignant', 'Benign', 'Benign', 'Benign', 'Benign',
#        'Malignant', 'Benign', 'Benign', 'Malignant', 'Benign', 'Benign',
#        'Benign', 'Malignant', 'Benign', 'Benign', 'Benign', 'Malignant',
#        'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Malignant',
#        'Malignant', 'Benign', 'Malignant', 'Benign', 'Benign', 'Benign',
#        'Benign', 'Malignant', 'Benign', 'Benign', 'Malignant', 'Benign',
#        'Malignant', 'Benign', 'Malignant', 'Benign', 'Benign', 'Benign',
#        'Malignant', 'Malignant', 'Benign', 'Malignant', 'Benign',
# ...

# %%
y_test
# Out:
# 198    Malignant
# 146    Malignant
# 278       Benign
# 41     Malignant
# 95     Malignant
# 357       Benign
# 525       Benign
# 403       Benign
# 332       Benign
# 174       Benign
# 105    Malignant
# 536    Malignant
# 10     Malignant
# 237    Malignant
# 259    Malignant
# 294       Benign
# 101       Benign
# 107       Benign
# 184    Malignant
# 378       Benign
# 0      Malignant
# 90        Benign
# 359       Benign
# 539       Benign
# 55        Benign
# 322       Benign
# 363       Benign
# 34     Malignant
# 135    Malignant
# 431       Benign
#          ...
# 361       Benign
# 491       Benign
# 26     Malignant
# 492    Malignant
# 430    Malignant
# 290       Benign
# 197    Malignant
# 324       Benign
# 256    Malignant
# 194    Malignant
# 532       Benign
# 227       Benign
# 172    Malignant
# 515       Benign
# 189       Benign
# 180    Malignant
# 464       Benign
# 58        Benign
# 443       Benign
# 297    Malignant
# 261    Malignant
# ...

# %%
from sklearn.metrics import confusion_matrix
clf_cm_test = confusion_matrix(y_test,y_pred)
clf_cm_test
# Out:
# array([[67,  4],
#        [ 9, 34]], dtype=int64)

# %%
# ACCURACY OF CLASSIFIER IS CHECKED HERE 
accuracy = clf.score(x_test,y_test)

# %%
print(accuracy)
# Out:
# 0.8859649122807017

# %%
# new data i.e never seen before data 
example_measure = np.array([15.44,12.54,150.9,998,0.2345,0.3452,0.2891,0.1234,0.3421,0.06879,2.076,0.8079,7.274,168.7,
                           0.009786,0.03804,0.04372,0.02785,0.02002,0.007621,28.75,16.44,192.7,2025,0.1723,0.7752,0.7121,0.3421
                           ,0.4802,0.1278])

# %%
# test new data
example_measure = example_measure.reshape(1,-1)  # RESHAPING THE DATA

# %%
prediction = clf.predict(example_measure)

# %%
print(prediction)
# Out:
# ['Malignant']

# %%
# PERFORMING LOGISTIC REGRESSION 
from sklearn.linear_model.logistic import LogisticRegression
cls = LogisticRegression(random_state = 0)
lr_cls = cls.fit(x_train,y_train)

# %%
# PREDICTING ON TEST AND TRAIN DATA
lr_y_test = lr_cls.predict(x_test)    # use this function to predict new data
lr_y_test
# Out:
# array(['Malignant', 'Benign', 'Benign', 'Benign', 'Malignant', 'Benign',
#        'Benign', 'Benign', 'Benign', 'Benign', 'Malignant', 'Benign',
#        'Malignant', 'Malignant', 'Malignant', 'Benign', 'Benign',
#        'Benign', 'Malignant', 'Benign', 'Malignant', 'Benign', 'Benign',
#        'Benign', 'Benign', 'Benign', 'Benign', 'Malignant', 'Benign',
#        'Benign', 'Malignant', 'Benign', 'Benign', 'Benign', 'Benign',
#        'Malignant', 'Benign', 'Benign', 'Malignant', 'Benign', 'Benign',
#        'Benign', 'Malignant', 'Benign', 'Benign', 'Benign', 'Malignant',
#        'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Malignant',
#        'Malignant', 'Benign', 'Malignant', 'Benign', 'Benign', 'Benign',
#        'Benign', 'Malignant', 'Benign', 'Benign', 'Malignant',
#        'Malignant', 'Malignant', 'Benign', 'Malignant', 'Benign',
#        'Benign', 'Benign', 'Malignant', 'Malignant', 'Benign',
# ...

# %%
accuracy_LR = cls.score(x_test,y_test)

# %%
accuracy_LR
# Out:
# 0.9122807017543859

# %%
 # more accurate than Knn

# %% [markdown]
# # support vector machine (SVM)

# %%
# support vector classification
from sklearn.svm import SVC
sc = SVC(kernel='rbf')
sc_classifier = sc.fit(x_train,y_train)  # model building

# %%
# predicting on test and train data 
svc_y_test = sc_classifier.predict(x_test)
print(svc_y_test)
# Out:
# ['Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
# ...

# %%
svc_y_train = sc_classifier.predict(x_train) # training data
print(svc_y_train)                      # predicting on train data
# Out:
# ['Benign' 'Benign' 'Malignant' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Malignant' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Malignant'
#  'Benign' 'Malignant' 'Malignant' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Malignant' 'Malignant' 'Benign' 'Benign' 'Benign' 'Malignant' 'Benign'
#  'Benign' 'Malignant' 'Benign' 'Benign' 'Malignant' 'Benign' 'Benign'
#  'Malignant' 'Malignant' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Malignant' 'Malignant' 'Malignant' 'Malignant' 'Malignant'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Malignant' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Malignant' 'Benign' 'Malignant' 'Malignant'
#  'Malignant' 'Benign' 'Malignant' 'Benign' 'Malignant' 'Benign'
#  'Malignant' 'Malignant' 'Benign' 'Malignant' 'Malignant' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Malignant' 'Benign' 'Benign'
# ...

# %%
# building confusion matrix on test and train
from sklearn.metrics import confusion_matrix
svc_cm_test = confusion_matrix(y_test,svc_y_test)
svc_cm_test
# Out:
# array([[71,  0],
#        [43,  0]], dtype=int64)

# %%
svc_cm_train = confusion_matrix(y_train,svc_y_train)
svc_cm_train
# Out:
# array([[286,   0],
#        [  0, 169]], dtype=int64)

# %%
# accuracy classification score
from sklearn.metrics import accuracy_score
svc_acc_test = accuracy_score(y_test,svc_y_test) # for test data
svc_acc_test
# Out:
# 0.6228070175438597

# %%
svc_acc_train = accuracy_score(y_train,svc_y_train) # for test data
svc_acc_train
# Out:
# 1.0

# %% [markdown]
# # Decision tree classifier

# %%
#Descision tree classifier
from sklearn.tree import DecisionTreeClassifier

dtc_clf = DecisionTreeClassifier()
dtc_clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
# Predicting on test and train data
dtc_y_test = dtc_clf.predict(x_test)
dtc_y_test
# Out:
# array(['Malignant', 'Malignant', 'Benign', 'Benign', 'Malignant',
#        'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Malignant',
#        'Benign', 'Malignant', 'Malignant', 'Malignant', 'Benign',
#        'Benign', 'Benign', 'Malignant', 'Benign', 'Malignant', 'Benign',
#        'Benign', 'Benign', 'Benign', 'Benign', 'Malignant', 'Malignant',
#        'Benign', 'Benign', 'Malignant', 'Benign', 'Benign', 'Benign',
#        'Benign', 'Malignant', 'Benign', 'Benign', 'Malignant', 'Benign',
#        'Benign', 'Benign', 'Malignant', 'Benign', 'Benign', 'Benign',
#        'Malignant', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign',
#        'Malignant', 'Malignant', 'Benign', 'Malignant', 'Benign',
#        'Malignant', 'Benign', 'Benign', 'Malignant', 'Benign', 'Benign',
#        'Malignant', 'Malignant', 'Malignant', 'Benign', 'Malignant',
#        'Benign', 'Benign', 'Benign', 'Malignant', 'Benign', 'Benign',
# ...

# %%
# model and training data
dtc_y_train = dtc_clf.predict(x_train)
dtc_y_train
# Out:
# array(['Benign', 'Benign', 'Malignant', 'Benign', 'Benign', 'Benign',
#        'Benign', 'Malignant', 'Benign', 'Benign', 'Benign', 'Benign',
#        'Benign', 'Malignant', 'Benign', 'Malignant', 'Malignant',
#        'Benign', 'Benign', 'Benign', 'Benign', 'Malignant', 'Malignant',
#        'Benign', 'Benign', 'Benign', 'Malignant', 'Benign', 'Benign',
#        'Malignant', 'Benign', 'Benign', 'Malignant', 'Benign', 'Benign',
#        'Malignant', 'Malignant', 'Benign', 'Benign', 'Benign', 'Benign',
#        'Benign', 'Benign', 'Malignant', 'Malignant', 'Malignant',
#        'Malignant', 'Malignant', 'Benign', 'Benign', 'Benign', 'Benign',
#        'Malignant', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign',
#        'Malignant', 'Benign', 'Malignant', 'Malignant', 'Malignant',
#        'Benign', 'Malignant', 'Benign', 'Malignant', 'Benign',
#        'Malignant', 'Malignant', 'Benign', 'Malignant', 'Malignant',
#        'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign',
# ...

# %%
# confusion matrix on test
from sklearn.metrics import confusion_matrix
dtc_cm_test = confusion_matrix(y_test,dtc_y_test)
dtc_cm_test
# Out:
# array([[67,  4],
#        [ 6, 37]], dtype=int64)

# %%
accuracy_dtc = dtc_clf.score(x_test,y_test)
accuracy_dtc
# Out:
# 0.9122807017543859

# %% [markdown]
# # Random Forest classifier

# %%
# Build Random Forest classifier
from sklearn.ensemble import RandomForestClassifier
rmf = RandomForestClassifier(max_depth = 3, random_state = 0)
rf_classi = rmf.fit(x_train,y_train)

# %%
# predicting on test and train data
rf_y_test = rf_classi.predict(x_test)
rf_y_test
# Out:
# array(['Malignant', 'Malignant', 'Benign', 'Benign', 'Malignant',
#        'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Malignant',
#        'Benign', 'Malignant', 'Malignant', 'Malignant', 'Benign',
#        'Benign', 'Benign', 'Malignant', 'Benign', 'Malignant', 'Benign',
#        'Benign', 'Benign', 'Benign', 'Benign', 'Malignant', 'Malignant',
#        'Benign', 'Benign', 'Malignant', 'Benign', 'Benign', 'Benign',
#        'Benign', 'Malignant', 'Benign', 'Benign', 'Malignant', 'Benign',
#        'Benign', 'Benign', 'Malignant', 'Benign', 'Benign', 'Benign',
#        'Malignant', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign',
#        'Malignant', 'Malignant', 'Benign', 'Malignant', 'Benign',
#        'Malignant', 'Benign', 'Benign', 'Malignant', 'Benign', 'Benign',
#        'Malignant', 'Benign', 'Malignant', 'Benign', 'Malignant',
#        'Benign', 'Benign', 'Benign', 'Malignant', 'Benign', 'Benign',
# ...

# %%
rf_y_train = rf_classi.predict(x_train)
rf_y_train
# Out:
# array(['Benign', 'Benign', 'Malignant', 'Benign', 'Benign', 'Benign',
#        'Benign', 'Malignant', 'Benign', 'Benign', 'Benign', 'Benign',
#        'Benign', 'Malignant', 'Benign', 'Malignant', 'Malignant',
#        'Benign', 'Benign', 'Benign', 'Benign', 'Malignant', 'Malignant',
#        'Benign', 'Benign', 'Benign', 'Malignant', 'Benign', 'Benign',
#        'Malignant', 'Benign', 'Benign', 'Malignant', 'Benign', 'Benign',
#        'Malignant', 'Malignant', 'Benign', 'Benign', 'Benign', 'Benign',
#        'Benign', 'Benign', 'Malignant', 'Malignant', 'Malignant',
#        'Malignant', 'Malignant', 'Benign', 'Benign', 'Benign', 'Benign',
#        'Malignant', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign',
#        'Malignant', 'Benign', 'Malignant', 'Malignant', 'Malignant',
#        'Benign', 'Malignant', 'Benign', 'Malignant', 'Benign',
#        'Malignant', 'Malignant', 'Benign', 'Malignant', 'Malignant',
#        'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign',
# ...

# %%
# build confusion Matrix on test and train
from sklearn.metrics import confusion_matrix
rf_cm_test = confusion_matrix(y_test,rf_y_test)
rf_cm_test
# Out:
# array([[67,  4],
#        [ 5, 38]], dtype=int64)

# %%
rf_cm_train = confusion_matrix(y_train,rf_y_train)
rf_cm_train                                             
 # FN are more in treain coz size of train is more than test data and hence while walking throuh
    # the data ...to generate comparisions and weights ...we get more errors/miss classification
# Out:
# array([[283,   3],
#        [  8, 161]], dtype=int64)

# %%
# precission Score on test and train
from sklearn.metrics import precision_score
rf_precision_test = precision_score(y_test,rf_y_test,average="weighted")
print(rf_precision_test) # test
rf_precision_train = precision_score(y_train , rf_y_train , average="weighted")
print(rf_precision_train) # train data
# Out:
# 0.9208263714842663
# 0.9759252607253611

# %%
from sklearn.metrics import recall_score
rf_recall_test = recall_score(y_test,rf_y_test,average="weighted")
print(rf_recall_test)
rf_recall_train = recall_score(y_train,rf_y_train,average="weighted")
print(rf_recall_train)
# Out:
# 0.9210526315789473
# 0.9758241758241758

# %%
# ADABOOST


# perform adaboost
from sklearn import model_selection
from sklearn.ensemble import AdaBoostClassifier
seed = 7  # no of data points initially taken
num_trees = 30
kfold = model_selection.KFold(n_splits =10, random_state=seed)
model = AdaBoostClassifier(n_estimators=num_trees,random_state=seed)
results = model_selection.cross_val_score(model,x_train,y_train,cv=kfold)

# %%
results# accuracy of various classifiers
# Out:
# array([0.95652174, 0.97826087, 0.95652174, 0.95652174, 0.97826087,
#        0.97777778, 0.95555556, 0.97777778, 0.97777778, 0.97777778])

# %%
results.mean()
# Out:
# 0.9692753623188406

# %% [markdown]
# ROUGH : ON OWN (from below)

# %%
ab = model.fit(x_train,y_train)

# %%
ab_y_predict = model.predict(x_test)

# %%
ab_y_predict
# Out:
# array(['Malignant', 'Malignant', 'Benign', 'Benign', 'Malignant',
#        'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Malignant',
#        'Benign', 'Malignant', 'Malignant', 'Malignant', 'Benign',
#        'Benign', 'Benign', 'Malignant', 'Benign', 'Malignant', 'Benign',
#        'Benign', 'Benign', 'Benign', 'Benign', 'Malignant', 'Malignant',
#        'Benign', 'Benign', 'Malignant', 'Benign', 'Benign', 'Benign',
#        'Benign', 'Malignant', 'Benign', 'Benign', 'Malignant', 'Benign',
#        'Benign', 'Benign', 'Malignant', 'Benign', 'Benign', 'Benign',
#        'Malignant', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign',
#        'Malignant', 'Malignant', 'Benign', 'Malignant', 'Benign',
#        'Benign', 'Benign', 'Benign', 'Malignant', 'Benign', 'Benign',
#        'Malignant', 'Benign', 'Malignant', 'Benign', 'Malignant',
#        'Benign', 'Benign', 'Benign', 'Malignant', 'Benign', 'Benign',
# ...

# %%
ab_cm_test = confusion_matrix(y_test,ab_y_predict)
ab_cm_test
# Out:
# array([[69,  2],
#        [ 7, 36]], dtype=int64)
