# %%
import pandas as pd

# %%
import numpy as np

# %%
d = ["a","b","c"]

# %%
g = [1,2,3]

# %%
sam = pd.Series(d,g)

# %%
sam[2]
# Out:
# 'b'

# %%
sam
# Out:
# 1    a
# 2    b
# 3    c
# dtype: object

# %% [raw]
# # series is just a labelled numpy array , but can hold data other than numeric also

# %%
s =np.array(d)

# %%
s
# Out:
# array(['a', 'b', 'c'], dtype='<U1')

# %%
h =np.array(d)

# %%
h+s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-ff067413c612> in <module>()
# ----> 1 h+s
#
# TypeError: ufunc 'add' did not contain a loop with signature matching types dtype('<U1') dtype('<U1') dtype('<U1')

# %% [raw]
# Hence it is useless to have a numpy array of strings

# %%
np.random.seed(1)

# %%
from numpy.random import randn

# %%
df = pd.DataFrame(randn(5,4),["A","B","C","D","E"],["P","Q","R","S"])

# %%
df
# Out:
#           P         Q         R         S
# A  1.624345 -0.611756 -0.528172 -1.072969
# B  0.865408 -2.301539  1.744812 -0.761207
# C  0.319039 -0.249370  1.462108 -2.060141
# D -0.322417 -0.384054  1.133769 -1.099891
# E -0.172428 -0.877858  0.042214  0.582815

# %%
df["P"]
# Out:
# A    1.624345
# B    0.865408
# C    0.319039
# D   -0.322417
# E   -0.172428
# Name: P, dtype: float64

# %%
df[["P","Q"]]
# Out:
#           P         Q
# A  1.624345 -0.611756
# B  0.865408 -2.301539
# C  0.319039 -0.249370
# D -0.322417 -0.384054
# E -0.172428 -0.877858

# %%
df.head(3)
# Out:
#           P         Q         R         S
# A  1.624345 -0.611756 -0.528172 -1.072969
# B  0.865408 -2.301539  1.744812 -0.761207
# C  0.319039 -0.249370  1.462108 -2.060141

# %%
import pandas as pd

# %%
import numpy as np

# %%
import os

# %%
os.getcwd()
# Out:
# 'R:\\academics\\XYZ\\Data Science udemy\\Python-Data-Science-and-Machine-Learning-Bootcamp\\Python-Data-Science-and-Machine-Learning-Bootcamp'

# %%
os.chdir("R:\\academics\\XYZ\\Data Science udemy\\Python-Data-Science-and-Machine-Learning-Bootcamp\\Python-Data-Science-and-Machine-Learning-Bootcamp")

# %%
df1 = pd.read_csv("sales.csv")

# %%
df1
# Out:
#     Sales Executive       Name  Gender  Age   Location  Sales ( in Rs)
# 0                 1     Mahesh    Male   25  Hyderabad              50
# 1                 2     Suresh    Male   22  Hyderabad              75
# 2                 3      Vijay    Male   20  Bangalore              11
# 3                 4     Ramesh    Male   27  Bangalore              77
# 4                 5   Jagadish    Male   28     Mumbai              45
# 5                 6     Harish    Male   24  Hyderabad              52
# 6                 7      Karan    Male   24  Bangalore              26
# 7                 8       Raju    Male   23     Mumbai              24
# 8                 9       Maya  Female   24     Mumbai              28
# 9                10       Rani  Female   30     Mumbai              31
# 10               11    Lakshmi  Female   19  Bangalore              36
# 11               12      Roopa  Female   24  Hyderabad              72
# ...

# %%
df
# Out:
#           P         Q         R         S
# A  1.624345 -0.611756 -0.528172 -1.072969
# B  0.865408 -2.301539  1.744812 -0.761207
# C  0.319039 -0.249370  1.462108 -2.060141
# D -0.322417 -0.384054  1.133769 -1.099891
# E -0.172428 -0.877858  0.042214  0.582815

# %%
df["new"] = df["P"] + df["Q"]

# %%
df
# Out:
#           P         Q         R         S       new
# A  1.624345 -0.611756 -0.528172 -1.072969  1.012589
# B  0.865408 -2.301539  1.744812 -0.761207 -1.436131
# C  0.319039 -0.249370  1.462108 -2.060141  0.069669
# D -0.322417 -0.384054  1.133769 -1.099891 -0.706472
# E -0.172428 -0.877858  0.042214  0.582815 -1.050287

# %%
df.drop("E")
# Out:
#           P         Q         R         S       new
# A  1.624345 -0.611756 -0.528172 -1.072969  1.012589
# B  0.865408 -2.301539  1.744812 -0.761207 -1.436131
# C  0.319039 -0.249370  1.462108 -2.060141  0.069669
# D -0.322417 -0.384054  1.133769 -1.099891 -0.706472

# %%
df.drop("new",axis=1)
# Out:
#           P         Q         R         S
# A  1.624345 -0.611756 -0.528172 -1.072969
# B  0.865408 -2.301539  1.744812 -0.761207
# C  0.319039 -0.249370  1.462108 -2.060141
# D -0.322417 -0.384054  1.133769 -1.099891
# E -0.172428 -0.877858  0.042214  0.582815

# %%
df
# Out:
#           P         Q         R         S       new
# A  1.624345 -0.611756 -0.528172 -1.072969  1.012589
# B  0.865408 -2.301539  1.744812 -0.761207 -1.436131
# C  0.319039 -0.249370  1.462108 -2.060141  0.069669
# D -0.322417 -0.384054  1.133769 -1.099891 -0.706472
# E -0.172428 -0.877858  0.042214  0.582815 -1.050287

# %%
df1[["Gender","Age","Location"]]
# Out:
#     Gender  Age   Location
# 0     Male   25  Hyderabad
# 1     Male   22  Hyderabad
# 2     Male   20  Bangalore
# 3     Male   27  Bangalore
# 4     Male   28     Mumbai
# 5     Male   24  Hyderabad
# 6     Male   24  Bangalore
# 7     Male   23     Mumbai
# 8   Female   24     Mumbai
# 9   Female   30     Mumbai
# 10  Female   19  Bangalore
# 11  Female   24  Hyderabad
# 12  Female   26  Hyderabad
# 13  Female   26  Hyderabad
# 14  Female   21  Bangalore
# 15  Female   24  Bangalore
# 16  Female   29     Mumbai
# 17  Female   27     Mumbai
# 18  Female   24  Hyderabad
# 19  Female   25  Hyderabad

# %%
df1.loc[[0,1,2,3],["Gender","Age","Location","Sales ( in Rs)"]]
# Out:
#   Gender  Age   Location  Sales ( in Rs)
# 0   Male   25  Hyderabad              50
# 1   Male   22  Hyderabad              75
# 2   Male   20  Bangalore              11
# 3   Male   27  Bangalore              77

# %%
df
# Out:
#           P         Q         R         S       new
# A  1.624345 -0.611756 -0.528172 -1.072969  1.012589
# B  0.865408 -2.301539  1.744812 -0.761207 -1.436131
# C  0.319039 -0.249370  1.462108 -2.060141  0.069669
# D -0.322417 -0.384054  1.133769 -1.099891 -0.706472
# E -0.172428 -0.877858  0.042214  0.582815 -1.050287

# %%
df.loc[["A","C","D"],["P","R","S"]]
# Out:
#           P         R         S
# A  1.624345 -0.528172 -1.072969
# C  0.319039  1.462108 -2.060141
# D -0.322417  1.133769 -1.099891

# %%
df.loc[["C"],["R","S"]]
# Out:
#           R         S
# C  1.462108 -2.060141

# %%
df.loc["F"] = df.loc["E"] + df.loc["D"]

# %%
df
# Out:
#           P         Q         R         S       new
# A  1.624345 -0.611756 -0.528172 -1.072969  1.012589
# B  0.865408 -2.301539  1.744812 -0.761207 -1.436131
# C  0.319039 -0.249370  1.462108 -2.060141  0.069669
# D -0.322417 -0.384054  1.133769 -1.099891 -0.706472
# E -0.172428 -0.877858  0.042214  0.582815 -1.050287
# F -0.494845 -1.261913  1.175983 -0.517076 -1.756758

# %%
df.loc[["A","D","F"],["Q"]]
# Out:
#           Q
# A -0.611756
# D -0.384054
# F -1.261913

# %%
df[df["P"]>0]
# Out:
#           P         Q         R         S       new
# A  1.624345 -0.611756 -0.528172 -1.072969  1.012589
# B  0.865408 -2.301539  1.744812 -0.761207 -1.436131
# C  0.319039 -0.249370  1.462108 -2.060141  0.069669

# %%
df[df.loc[["A"]]>0]
# Out:
#           P   Q   R   S       new
# A  1.624345 NaN NaN NaN  1.012589
# B       NaN NaN NaN NaN       NaN
# C       NaN NaN NaN NaN       NaN
# D       NaN NaN NaN NaN       NaN
# E       NaN NaN NaN NaN       NaN
# F       NaN NaN NaN NaN       NaN
